# %%
LOC = r"C:\Users\user\Documents\NewProject\pipeline\airflow\dags"
IF_ERROR = r"Set-ExecutionPolicy Unrestricted -Scope Process"
ENV = r".\env\Scripts\activate"

PATH = f"cd {LOC}; {IF_ERROR}; {ENV}"

# %%
PATH
# Out:
# 'cd C:\\Users\\user\\Documents\\NewProject\\pipeline\\airflow\\dags; Set-ExecutionPolicy Unrestricted -Scope Process; .\\env\\Scripts\\activate'
